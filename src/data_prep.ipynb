# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd

# %%
# settings
dates_idx = pd.date_range(start='2011-01-01', end='2022-12-31', 
                          freq='1D') # When there will be new data then to change, only for the purpose of test data

# %% [markdown]
# # 2. Load data

# %% [markdown]
# ## 2.1 Datasets from the KGHM company

# %%
meteo = pd.read_excel('../data/meteo - sample.xlsx', sheet_name='dane', header=[0, 1])

# taking only Date and sum of rain
meteo = meteo.loc[:, meteo.columns.get_level_values(1).isin(['Data', 'Suma opadów [mm]'])]

meteo.columns = ['Data'] + [f'{col_name} Suma opadów [mm]' for col_name in meteo.columns.get_level_values(0)][1:]

# set the column type for column with date
meteo['Data'] = pd.to_datetime(meteo['Data'], format='%d-%m-%Y')

# Fill in the missing values with the number 0.05
meteo = meteo.fillna(0.05)

################# Add new dates for modeling purposes | To change when will be new datasets
meteo = meteo.set_index('Data').reindex(dates_idx).reset_index().rename({'index': 'Data'}, axis=1)
meteo = meteo.bfill().ffill()

# Add new columns to compare with y
meteo['GŁOGÓW (151160060) Suma opadów [mm]'] = meteo['BARDO ŚLĄSKIE (250160410) Suma opadów [mm]']
meteo['RACIBÓRZ-MIEDONIA (150180060) Suma opadów [mm]'] = meteo['BOLESŁAWÓW (250160610) Suma opadów [mm]']

###############################################################################################

meteo
# Out:
#            Data  BARDO ŚLĄSKIE (250160410) Suma opadów [mm]  \
# 0    2011-01-01                                         0.2
# 1    2011-01-02                                         0.2
# 2    2011-01-03                                         0.2
# 3    2011-01-04                                         0.2
# 4    2011-01-05                                         0.2
# ...         ...                                         ...
# 4378 2022-12-27                                         3.8
# 4379 2022-12-28                                         3.8
# 4380 2022-12-29                                         3.8
# 4381 2022-12-30                                         3.8
# 4382 2022-12-31                                         3.8
#
#       BIERUTÓW (251170270) Suma opadów [mm]  \
# 0                                       0.5
# 1                                       0.5
# 2                                       0.5
# 3                                       0.5
# 4                                       0.5
# ...                                     ...
# 4378                                    6.8
# 4379                                    6.8
# 4380                                    6.8
# 4381                                    6.8
# 4382                                    6.8
#
#       BOLESŁAWÓW (250160610) Suma opadów [mm]  \
# 0                                         0.5
# 1                                         0.5
# 2                                         0.5
# 3                                         0.5
# 4                                         0.5
# ...                                       ...
# 4378                                      2.0
# 4379                                      2.0
# 4380                                      2.0
# 4381                                      2.0
# 4382                                      2.0
#
#       BOLKÓW (250160030) Suma opadów [mm]  BORÓW (250160070) Suma opadów [mm]  \
# 0                                     0.7                                 0.2
# 1                                     0.7                                 0.2
# 2                                     0.7                                 0.2
# 3                                     0.7                                 0.2
# 4                                     0.7                                 0.2
# ...                                   ...                                 ...
# 4378                                  4.7                                 4.8
# 4379                                  4.7                                 4.8
# 4380                                  4.7                                 4.8
# 4381                                  4.7                                 4.8
# 4382                                  4.7                                 4.8
#
#       BRZEG (250170050) Suma opadów [mm]  \
# 0                                   0.05
# 1                                   0.05
# 2                                   0.05
# 3                                   0.05
# 4                                   0.05
# ...                                  ...
# 4378                                1.70
# 4379                                1.70
# 4380                                1.70
# 4381                                1.70
# 4382                                1.70
#
#       BRZEG DOLNY (251160230) Suma opadów [mm]  \
# 0                                          0.8
# 1                                          0.8
# 2                                          0.8
# 3                                          0.8
# 4                                          0.8
# ...                                        ...
# 4378                                       5.1
# 4379                                       5.1
# 4380                                       5.1
# 4381                                       5.1
# 4382                                       5.1
#
#       CHWAŁKOWICE (251160170) Suma opadów [mm]  \
# 0                                          0.8
# 1                                          0.8
# 2                                          0.8
# 3                                          0.8
# 4                                          0.8
# ...                                        ...
# 4378                                       5.2
# 4379                                       5.2
# 4380                                       5.2
# 4381                                       5.2
# 4382                                       5.2
#
#       GŁOGÓW (151160060) Suma opadów [mm]  \
# 0                                     0.2
# 1                                     0.2
# 2                                     0.2
# 3                                     0.2
# 4                                     0.2
# ...                                   ...
# 4378                                  3.8
# 4379                                  3.8
# 4380                                  3.8
# 4381                                  3.8
# 4382                                  3.8
#
#       RACIBÓRZ-MIEDONIA (150180060) Suma opadów [mm]
# 0                                                0.5
# 1                                                0.5
# 2                                                0.5
# 3                                                0.5
# 4                                                0.5
# ...                                              ...
# 4378                                             2.0
# 4379                                             2.0
# 4380                                             2.0
# 4381                                             2.0
# 4382                                             2.0
#
# [4383 rows x 11 columns]

# %%
hydro = pd.read_excel('../data/hydro - sample.xlsx', sheet_name='hydro', header=[1, 2])

# taking only Date and level of water
hydro = hydro.loc[:, hydro.columns.get_level_values(1).isin(['Data', 'Stan wody [cm]'])]

hydro.columns = ['Data'] + [f'{col_name} Stan wody [cm]' for col_name in hydro.columns.get_level_values(0)][1:]

# set the column type for column with date
hydro['Data'] = pd.to_datetime(hydro['Data'], format='%Y-%m-%d')

################# Add new dates for modeling purposes | To change when will be new datasets
hydro = hydro.set_index('Data').reindex(dates_idx).reset_index().rename({'index': 'Data'}, axis=1)
hydro = hydro.bfill().ffill()
###############################################################################################

hydro
# Out:
#            Data  GŁOGÓW (151160060) Stan wody [cm]  \
# 0    2011-01-01                              199.0
# 1    2011-01-02                              199.0
# 2    2011-01-03                              199.0
# 3    2011-01-04                              199.0
# 4    2011-01-05                              199.0
# ...         ...                                ...
# 4378 2022-12-27                              203.0
# 4379 2022-12-28                              203.0
# 4380 2022-12-29                              203.0
# 4381 2022-12-30                              203.0
# 4382 2022-12-31                              203.0
#
#       RACIBÓRZ-MIEDONIA (150180060) Stan wody [cm]
# 0                                            118.0
# 1                                            118.0
# 2                                            118.0
# 3                                            118.0
# 4                                            118.0
# ...                                            ...
# 4378                                         114.0
# 4379                                         114.0
# 4380                                         114.0
# 4381                                         114.0
# 4382                                         114.0
#
# [4383 rows x 3 columns]

# %% [markdown]
# ## 2.2 Public data

# %%
# prognoza pogody: wilgotność, temperatura, opady? IMGW?

# %% [markdown]
# # 3. Data Preprocessing

# %%
prepared_dataset = pd.merge(hydro, meteo, how='left', on=['Data'])
prepared_dataset
# Out:
#            Data  GŁOGÓW (151160060) Stan wody [cm]  \
# 0    2011-01-01                              199.0
# 1    2011-01-02                              199.0
# 2    2011-01-03                              199.0
# 3    2011-01-04                              199.0
# 4    2011-01-05                              199.0
# ...         ...                                ...
# 4378 2022-12-27                              203.0
# 4379 2022-12-28                              203.0
# 4380 2022-12-29                              203.0
# 4381 2022-12-30                              203.0
# 4382 2022-12-31                              203.0
#
#       RACIBÓRZ-MIEDONIA (150180060) Stan wody [cm]  \
# 0                                            118.0
# 1                                            118.0
# 2                                            118.0
# 3                                            118.0
# 4                                            118.0
# ...                                            ...
# 4378                                         114.0
# 4379                                         114.0
# 4380                                         114.0
# 4381                                         114.0
# 4382                                         114.0
#
#       BARDO ŚLĄSKIE (250160410) Suma opadów [mm]  \
# 0                                            0.2
# 1                                            0.2
# 2                                            0.2
# 3                                            0.2
# 4                                            0.2
# ...                                          ...
# 4378                                         3.8
# 4379                                         3.8
# 4380                                         3.8
# 4381                                         3.8
# 4382                                         3.8
#
#       BIERUTÓW (251170270) Suma opadów [mm]  \
# 0                                       0.5
# 1                                       0.5
# 2                                       0.5
# 3                                       0.5
# 4                                       0.5
# ...                                     ...
# 4378                                    6.8
# 4379                                    6.8
# 4380                                    6.8
# 4381                                    6.8
# 4382                                    6.8
#
#       BOLESŁAWÓW (250160610) Suma opadów [mm]  \
# 0                                         0.5
# 1                                         0.5
# 2                                         0.5
# 3                                         0.5
# 4                                         0.5
# ...                                       ...
# 4378                                      2.0
# 4379                                      2.0
# 4380                                      2.0
# 4381                                      2.0
# 4382                                      2.0
#
#       BOLKÓW (250160030) Suma opadów [mm]  BORÓW (250160070) Suma opadów [mm]  \
# 0                                     0.7                                 0.2
# 1                                     0.7                                 0.2
# 2                                     0.7                                 0.2
# 3                                     0.7                                 0.2
# 4                                     0.7                                 0.2
# ...                                   ...                                 ...
# 4378                                  4.7                                 4.8
# 4379                                  4.7                                 4.8
# 4380                                  4.7                                 4.8
# 4381                                  4.7                                 4.8
# 4382                                  4.7                                 4.8
#
#       BRZEG (250170050) Suma opadów [mm]  \
# 0                                   0.05
# 1                                   0.05
# 2                                   0.05
# 3                                   0.05
# 4                                   0.05
# ...                                  ...
# 4378                                1.70
# 4379                                1.70
# 4380                                1.70
# 4381                                1.70
# 4382                                1.70
#
#       BRZEG DOLNY (251160230) Suma opadów [mm]  \
# 0                                          0.8
# 1                                          0.8
# 2                                          0.8
# 3                                          0.8
# 4                                          0.8
# ...                                        ...
# 4378                                       5.1
# 4379                                       5.1
# 4380                                       5.1
# 4381                                       5.1
# 4382                                       5.1
#
#       CHWAŁKOWICE (251160170) Suma opadów [mm]  \
# 0                                          0.8
# 1                                          0.8
# 2                                          0.8
# 3                                          0.8
# 4                                          0.8
# ...                                        ...
# 4378                                       5.2
# 4379                                       5.2
# 4380                                       5.2
# 4381                                       5.2
# 4382                                       5.2
#
#       GŁOGÓW (151160060) Suma opadów [mm]  \
# 0                                     0.2
# 1                                     0.2
# 2                                     0.2
# 3                                     0.2
# 4                                     0.2
# ...                                   ...
# 4378                                  3.8
# 4379                                  3.8
# 4380                                  3.8
# 4381                                  3.8
# 4382                                  3.8
#
#       RACIBÓRZ-MIEDONIA (150180060) Suma opadów [mm]
# 0                                                0.5
# 1                                                0.5
# 2                                                0.5
# 3                                                0.5
# 4                                                0.5
# ...                                              ...
# 4378                                             2.0
# 4379                                             2.0
# 4380                                             2.0
# 4381                                             2.0
# 4382                                             2.0
#
# [4383 rows x 13 columns]

# %%
prepared_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4383 entries, 0 to 4382
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data                                            4383 non-null   datetime64[ns]
#  1   GŁOGÓW (151160060) Stan wody [cm]               4383 non-null   float64
#  2   RACIBÓRZ-MIEDONIA (150180060) Stan wody [cm]    4383 non-null   float64
#  3   BARDO ŚLĄSKIE (250160410) Suma opadów [mm]      4383 non-null   float64
#  4   BIERUTÓW (251170270) Suma opadów [mm]           4383 non-null   float64
#  5   BOLESŁAWÓW (250160610) Suma opadów [mm]         4383 non-null   float64
#  6   BOLKÓW (250160030) Suma opadów [mm]             4383 non-null   float64
#  7   BORÓW (250160070) Suma opadów [mm]              4383 non-null   float64
#  8   BRZEG (250170050) Suma opadów [mm]              4383 non-null   float64
#  9   BRZEG DOLNY (251160230) Suma opadów [mm]        4383 non-null   float64
#  10  CHWAŁKOWICE (251160170) Suma opadów [mm]        4383 non-null   float64
#  11  GŁOGÓW (151160060) Suma opadów [mm]             4383 non-null   float64
#  12  RACIBÓRZ-MIEDONIA (150180060) Suma opadów [mm]  4383 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 479.4 KB

# %% [markdown]
# # 4. Save data

# %%
prepared_dataset.to_csv('../data/prepared_data.csv', index=False)
